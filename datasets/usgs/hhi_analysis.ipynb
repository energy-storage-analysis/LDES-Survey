# %%
import os
import numpy as np
import pandas as pd

df = pd.read_csv('USGS_HHI/Prices.csv')

df = df.where(df['Year'] == 2015).dropna(subset=['Year'])
df
# Out:
#      Element    Year      Dollars  Change in AbsoluteDollars  \
# 18        Li  2015.0     6.500000                   1.450000
# 36        Be  2015.0          NaN                        NaN
# 54         B  2015.0     0.770000                   0.000000
# 72         N  2015.0     0.504307                  -0.162591
# 90        Al  2015.0     1.944475                  -0.359353
# ...      ...     ...          ...                        ...
# 1026      Tb  2015.0   562.000000                -151.000000
# 1044      Tm  2015.0          NaN                        NaN
# 1062      Yb  2015.0          NaN                        NaN
# 1080       Y  2015.0     8.000000                  -8.000000
# 1098      Sc  2015.0  5100.000000                 100.000000
#
#      Change in Absolute Dollars (%)  Price Index  1998 Dollars  \
# 18                           28.71%     1.456785      4.461880
# 36                              NaN          NaN           NaN
# ...

# %%
df['Element'].values
# Out:
# array(['Li', 'Be', 'B', 'N', 'Al', 'P', 'S', 'K', 'Ca', 'Ti', 'V', 'Cr',
#        'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn', 'Ga', 'As', 'Se', 'Br', 'Sr',
#        'Rare Earths', 'Zr', 'Nb', 'Mo', 'Platinum Group', 'Ag', 'Cd',
#        'Sn', 'Sb', 'Te', 'I', 'Ba', 'Ta', 'W', 'Re', 'Au', 'Hg', 'Pb',
#        'Bi', 'Th', 'Pd', 'Pt', 'Ce', 'Dy', 'Er', 'Eu', 'Gd', 'Ho', 'La',
#        'Lu', 'Nd', 'Pr', 'Sm', 'Tb', 'Tm', 'Yb', 'Y', 'Sc'], dtype=object)
